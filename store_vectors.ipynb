# %%
# import thu vien
import os

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import  Model

from PIL import Image
import pickle
import numpy as np

# %%
path_dataset= 'anhhoa_resize'

# %%
# Ham tao model
def get_extract_model():
    vgg16_model = VGG16(weights="imagenet")
    extract_model = Model(inputs=vgg16_model.inputs, outputs = vgg16_model.get_layer("fc1").output)
    return extract_model

# %%
# Ham tien xu ly, chuyen doi hinh anh thanh tensor
def image_preprocess(img):
    img = img.resize((224,224))
    img = img.convert("RGB")
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x

def extract_vector(model, image_path):
    print("Xu ly : ", image_path)
    img = Image.open(image_path)
    img_tensor = image_preprocess(img)

    # Trich dac trung
    vector = model.predict(img_tensor)[0]
    # Chuan hoa vector = chia chia L2 norm (tu google search)
    vector = vector / np.linalg.norm(vector)
    return vector

# %%
# Khoi tao model
model = get_extract_model()

vectors = []
paths = []

for image_path in os.listdir(path_dataset):
    # Noi full path
    image_path_full = os.path.join(path_dataset, image_path)
    # Trich dac trung
    image_vector = extract_vector(model,image_path_full)
    # Add dac trung va full path vao list
    vectors.append(image_vector)
    paths.append(image_path_full)
# Out:
# Xu ly :  anhhoa_resize\1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# Xu ly :  anhhoa_resize\10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Xu ly :  anhhoa_resize\100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Xu ly :  anhhoa_resize\101.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\102.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Xu ly :  anhhoa_resize\103.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Xu ly :  anhhoa_resize\104.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Xu ly :  anhhoa_resize\105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Xu ly :  anhhoa_resize\106.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Xu ly :  anhhoa_resize\107.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Xu ly :  anhhoa_resize\108.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\109.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\11.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Xu ly :  anhhoa_resize\110.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\111.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\112.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\113.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\114.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\115.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\116.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\117.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\118.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\119.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\120.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\121.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Xu ly :  anhhoa_resize\122.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Xu ly :  anhhoa_resize\123.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Xu ly :  anhhoa_resize\124.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Xu ly :  anhhoa_resize\125.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\126.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Xu ly :  anhhoa_resize\127.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Xu ly :  anhhoa_resize\128.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\129.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\130.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\131.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\132.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\133.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\134.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\135.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\136.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\137.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\138.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Xu ly :  anhhoa_resize\139.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Xu ly :  anhhoa_resize\14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\140.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\141.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Xu ly :  anhhoa_resize\142.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\143.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\144.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\146.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Xu ly :  anhhoa_resize\147.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\148.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\149.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\151.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\152.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\153.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\154.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Xu ly :  anhhoa_resize\155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\156.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\157.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\158.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Xu ly :  anhhoa_resize\20.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\21.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\22.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\23.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\24.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Xu ly :  anhhoa_resize\25.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\26.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\27.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\28.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\29.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Xu ly :  anhhoa_resize\30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Xu ly :  anhhoa_resize\31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\32.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\34.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\36.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Xu ly :  anhhoa_resize\38.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Xu ly :  anhhoa_resize\39.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Xu ly :  anhhoa_resize\40.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Xu ly :  anhhoa_resize\41.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Xu ly :  anhhoa_resize\42.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Xu ly :  anhhoa_resize\43.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Xu ly :  anhhoa_resize\44.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Xu ly :  anhhoa_resize\45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Xu ly :  anhhoa_resize\46.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\47.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Xu ly :  anhhoa_resize\48.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Xu ly :  anhhoa_resize\49.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Xu ly :  anhhoa_resize\5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\51.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\52.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\53.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\54.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\55.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Xu ly :  anhhoa_resize\56.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Xu ly :  anhhoa_resize\57.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\58.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\59.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Xu ly :  anhhoa_resize\60.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Xu ly :  anhhoa_resize\61.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Xu ly :  anhhoa_resize\62.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Xu ly :  anhhoa_resize\63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\64.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Xu ly :  anhhoa_resize\65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\66.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\67.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\68.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Xu ly :  anhhoa_resize\69.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Xu ly :  anhhoa_resize\7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Xu ly :  anhhoa_resize\70.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Xu ly :  anhhoa_resize\71.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Xu ly :  anhhoa_resize\72.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Xu ly :  anhhoa_resize\73.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Xu ly :  anhhoa_resize\74.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\75.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\76.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\77.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Xu ly :  anhhoa_resize\78.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Xu ly :  anhhoa_resize\79.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Xu ly :  anhhoa_resize\8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Xu ly :  anhhoa_resize\80.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Xu ly :  anhhoa_resize\81.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Xu ly :  anhhoa_resize\82.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\83.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\84.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\85.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\86.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\87.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\88.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Xu ly :  anhhoa_resize\89.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Xu ly :  anhhoa_resize\9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Xu ly :  anhhoa_resize\90.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\91.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\92.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Xu ly :  anhhoa_resize\93.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Xu ly :  anhhoa_resize\94.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Xu ly :  anhhoa_resize\95.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Xu ly :  anhhoa_resize\96.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Xu ly :  anhhoa_resize\97.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Xu ly :  anhhoa_resize\98.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Xu ly :  anhhoa_resize\99.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step

# %%
# save vao file
vector_file = "vectors.pkl"
path_file = "paths.pkl"

pickle.dump(vectors, open(vector_file, "wb"))
pickle.dump(paths, open(path_file, "wb"))
